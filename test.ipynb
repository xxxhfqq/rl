# %%
from x_ml import PPO

ppo = PPO(device="cuda:3")
ppo.train()
# Out:
#   0%|          | 40/195312 [00:12<16:27:23,  3.30it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 4>()
#       1 from x_ml import PPO
#       3 ppo = PPO(device="cuda:2")
# ----> 4 ppo.train()
#
# File ~/xhf/rl/rl/x_ml/x_ppo.py:358, in PPO.train(self)
#     355 for update in range(total_updates):
#     356     self.update_step = update
# --> 358     batch, obs = self.rollout(obs)
#     359     self.update(batch, total_updates)
#     361     # eval & save
#
# File ~/xhf/rl/rl/x_ml/x_ppo.py:198, in PPO.rollout(self, obs)
#     195 dones_buf[t] = torch.tensor(terminated_mask, device=self.device, dtype=torch.float32)
#     197 # ====== 回合统计：用 terminated OR truncated ======
# --> 198 episode_done = np.logical_or(terminated, truncated)
#     199 self._running_ep_return += reward.astype(np.float32)
#     200 for i in range(N):
#
# ...
